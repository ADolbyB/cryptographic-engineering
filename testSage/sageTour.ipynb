# %% [markdown]
# ### Joel Brigida
# ### CDA-4321: Cryptographic Engineering
# ### This is a test to check `SageMath 10.0` Running on VS Code

# %% [markdown]
# #### Simple Operations: $ +, -, \times, \div, \, \^{} \, , \, \% $

# %%
print(3 + 56)
print(3 - 56)
print(12 / 24)
print(123 * 456)
print(57.1 ^ 1000)

a = 103
b = 25
c = a % b

print(f'c = {c}')
print(f'a % b = {mod(a, b)}')
# Out:
# 59
# -53
# 1/2
# 56088
# 4.32621646499942e1756
# c = 3
# a % b = 3

# %% [markdown]
# $$ \text{Creating A Matrix: }
# A =
# \begin{bmatrix}
# 1 & 2\\
# 3 & 4
# \end{bmatrix}
# $$
#
# $$ \text{Calculate Matrix Inverse: }
# A^{-1} =
# \begin{bmatrix}
# -2 & 1\\
# \frac{3}{2} & -\frac{1}{2} \,
# \end{bmatrix}
# $$

# %%
A = matrix([[1,2], [3,4]])

print(A, '\n')
print(A^(-1))
# Out:
# [1 2]
# [3 4]
#
# [  -2    1]
# [ 3/2 -1/2]

# %% [markdown]
# $$ \text{Integration Function:} \int \sqrt{x} \cdot \sqrt{1+x} \, \mathrm{d}x $$

# %%
x = var('x')
integrate(sqrt(x)*sqrt(1+x), x)
# Out:
# 1/4*((x + 1)^(3/2)/x^(3/2) + sqrt(x + 1)/sqrt(x))/((x + 1)^2/x^2 - 2*(x + 1)/x + 1) - 1/8*log(sqrt(x + 1)/sqrt(x) + 1) + 1/8*log(sqrt(x + 1)/sqrt(x) - 1)

# %% [markdown]
# #### Using MatPlotLib libraries to plot functions:
#
# $$ f(x) = \sin{(x)} + \sin{(1.6x)} $$

# %%
show(plot(sin(x) + sin(1.6*x), 0, 40))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# #### Perform Inverse Modulo Operation:
#
# $$ c = a^{-1} \, \text{mod } \, b $$

# %%
c = inverse_mod(a, b)
print(c)
# Out:
# 17

# %% [markdown]
# #### Find Greatest Common Denominator: `gcd(x, y)`

# %%
a = 100
b = 25
d = gcd(a, b)
print(f'GCD of {a} and {b} = {d}\n')

e = 110
f = 22
g = gcd(e, f)
print(f'GCD of {e} and {f} = {g}\n')

h = 110
j = 21
k = gcd(h, j)
print(f'GCD of {h} and {j} = {k}\n')
# Out:
# GCD of 100 and 25 = 25
#
# GCD of 110 and 22 = 22
#
# GCD of 110 and 21 = 1

# %% [markdown]
# #### Some Other Basic Functions:

# %%
# Extended Euclidean algorithm parameter of two integers
c = xgcd(a,b)
print(f'The XGCD of {a} and {b} = {c}\n')

# Generate a list of bits for an integer
a = 16
c = a.bits()
print(f'The binary bits of {a} (Little Endian) = {c}\n')

# Generate a list of digits of base b (b=2 is the .bits function) for an integer
# and extend to size n (fill 0s)
a = 32
b = 2
n = 0
c = a.digits(base=b, padto=n)
print(f'{a} in decimal = {c} as a list in base {b}\n')

# Convert list back to Integer (Reverse of previous function)
a = Integer(c, base=b)
print(f'Convert {c} back to the integer value = {a}\n')

# Get number of bits of an Integer
c = a.nbits()
print(f'Number of binary bits needed to represent {a} = {c}\n')

# Get number of digits of an Integer with base 10
a = 9999
c = a.ndigits()
print(f'Number of decimal digits needed to represent {a} = {c}\n')

# Create Field F_p
p = 101
K = GF(p)
print(K, '\n')

# Convert to hex
print(f'{a} decimal converted to hexadecimal = {hex(a)}')
print(f'{a} decimal converted to hexadecimal (w/o \'0x\' prefix) = {a.hex()}\n')

# Produce some random integer
c = ZZ.random_element()
print(f'The Random Number = {c}\n')

# Sometimes values will be printed as fraction or irrational value. 
# If you want decimal approximation of value, use this function
c = numerical_approx(a)
print(f'numerical_approx({a}) = {c}')
# Out:
# The XGCD of 100 and 25 = (25, 0, 1)
#
# The binary bits of 16 (Little Endian) = [0, 0, 0, 0, 1]
#
# 32 in decimal = [0, 0, 0, 0, 0, 1] as a list in base 2
#
# Convert [0, 0, 0, 0, 0, 1] back to the integer value = 32
#
# Number of binary bits needed to represent 32 = 6
#
# Number of decimal digits needed to represent 9999 = 4
#
# Finite Field of size 101
#
# 9999 decimal converted to hexadecimal = 0x270f
# 9999 decimal converted to hexadecimal (w/o '0x' prefix) = 270f
#
# The Random Number = 2
#
# numerical_approx(9999) = 9999.00000000000

# %% [markdown]
# #### Inversion using Fermat's Little Theorem:
# #### FLT method only works with prime modulus $$ x^{-1} = 17^{19-2} \bmod 19 = 9 $$

# %%
inverse_mod(17, 19)
# Out:
# 9
